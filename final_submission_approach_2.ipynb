# %%
# Decide how much augmentation is needed by adding the fraction
augment = 0.4

# %%
import librosa
import pandas as pd
import soundfile as sf
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
import pandas as pd
import os
import librosa
import numpy as np
from scipy.io import wavfile
from IPython.display import Audio
from utils import (
    train_test_split_util,
    meta,
    get_waves,
    extract_features,
    split_audio,
    bell,
    split_audio2,
    get_waves_5_sec,
    test_acc
)
from audiomentations import (
    Compose,
    AddGaussianNoise,
    TimeStretch,
    Gain,
    PitchShift,
    RoomSimulator,
)
from tensorflow.keras.callbacks import ModelCheckpoint
# Out:
# /var/folders/49/ptrwr_w135x7rbt0__3kv5080000gp/T/ipykernel_4479/3647293026.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Train Test Split using utils

# %%
train_x, test_x, train_y, test_y = train_test_split_util()
# Out:
# Function Name: train_test_split_util
# Time Taken: 0.2574 seconds

# %% [markdown]
# # Split the dataset

# %%
train_x, train_y = split_audio2(train_x, train_y, split_time=1, prefix_metadata_file="train")
test_x, test_y = split_audio2(test_x, test_y, split_time=1, prefix_metadata_file="test")

# %%
train_x_wave, train_x_sr = get_waves(train_x, base_path = "/Users/Licious/project/unipd/hda_dataset/audio/")
# Out:
# Function Name: get_waves
# Time Taken: 9.0946 seconds

# %%
test_x_wave, test_x_sr = get_waves(test_x, base_path = "/Users/Licious/project/unipd/hda_dataset/audio/")
# Out:
# Function Name: get_waves
# Time Taken: 0.9866 seconds

# %% [markdown]
# ## Augmentation

# %%
#erann

audio_augment = Compose([
        AddGaussianNoise(min_amplitude=0.01, max_amplitude=0.15, p=1),
        PitchShift(min_semitones=-6, max_semitones=6, p=1),
        TimeStretch(min_rate=.75, max_rate=1.25,p=1),
        # Gain(min_gain_in_db=-12, max_gain_in_db=-12, p=1),
        # RoomSimulator(p=1, leave_length_unchanged=True)
])

# %%
num_augmented = int(len(train_x_sr)*augment)
augmented_img, aug_train_y = None, None
if augment:
    #genreate augmented images from the first num_augmented clips and concatenate them to the train images
    augmented_img = np.array([audio_augment(samples=clip, sample_rate=train_x_sr[0]) for clip in train_x_wave[:num_augmented]])
    aug_train_y =  train_y[:num_augmented]

# %% [markdown]
# ## Feature Extraction

# %%
train = extract_features(train_x_wave, ft="mel", n_mfcc=128, sr=44100)
test = extract_features(test_x_wave, ft="mel", n_mfcc=128, sr=44100)
aug_train = extract_features(test_x_wave, ft="mel", n_mfcc=128, sr=44100)
# Out:
# Function Name: extract_features
# Time Taken: 32.0127 seconds
# Function Name: extract_features
# Time Taken: 7.8404 seconds
# Function Name: extract_features
# Time Taken: 7.1506 seconds

# %% [markdown]
# # Model creation and fiting

# %%
tf.compat.v1.set_random_seed(
    42
)

# %% [markdown]
# ### Model Create Erann

# %%
# erann

import tensorflow as tf
from tensorflow.keras import layers, models


def CC1(i):
    if i==1 or i==2:
      return 3
    elif i==4:
      return 6


def CC2(j):
    if j==1 or j==2:
      return 3
    elif j==4:
      return 5

def P(x):
    if x==1 or x==2:
        return 1
    elif x==4:
        return 2


def create_arb_block(input_tensor, x, y, c, layer=2):
    conv = None
    if layer != 1:
        conv = layers.BatchNormalization()(input_tensor)
        conv = layers.LeakyReLU(0.01)(conv)
        conv = layers.Conv2D(
            c, kernel_size=(CC1(x), CC1(y)), strides=(x, y), padding="same"
        )(conv)
    else:
        conv = layers.Conv2D(
            c, kernel_size=(CC1(x), CC1(y)), strides=(x, y), padding="same"
        )(input_tensor)

    conv = layers.BatchNormalization()(conv)
    conv = layers.LeakyReLU(0.01)(conv)
    conv = layers.Conv2D(c, (CC2(x), CC2(y)), strides=(1, 1), padding="same")(conv)

    if x != 1 or y != 1:
        combined_tensors = [conv]
        residual = layers.Conv2D(c, (1, 1), (x, y), padding="valid")(input_tensor)
        combined_tensors.append(residual)
        output_tensor = layers.Add()(combined_tensors)
        output_tensor = layers.Dropout(0.2)(output_tensor)
        return output_tensor
    return conv


def s(i):
    sm = 1
    return 2 if i > sm else 4



def create_eranns_architecture(input_shape, decreasing_temporal_size_parameter, num_classes):
    F0, T0, C0 = 128, 320, 1
    sm = decreasing_temporal_size_parameter
    W = 1

    model = models.Sequential()
    # Feature extractor
    erann_input = layers.Input(shape=input_shape)
    erann = layers.BatchNormalization()(erann_input)
    #Stage 0
    erann = create_arb_block(erann, 1, 1 , 8, layer = 1)
    erann = create_arb_block(erann, 1, 1 , 8,)
    erann = create_arb_block(erann, 1, 1 , 8)
    erann = create_arb_block(erann, 1, 1 , 8)

    #Stage 1
    erann = create_arb_block(erann, 2, s(1), 16)
    erann = create_arb_block(erann, 1, 1, 16)
    erann = create_arb_block(erann, 1, 1, 16)
    erann = create_arb_block(erann, 1, 1, 16)


    #Stage 2
    erann = create_arb_block(erann, 2, s(2), 32)
    erann = create_arb_block(erann, 1, 1, 32)
    erann = create_arb_block(erann, 1, 1, 32)
    erann = create_arb_block(erann, 1, 1, 32)


    #Stage 3
    erann = create_arb_block(erann, 2, s(3), 64)
    erann = create_arb_block(erann, 1, 1, 64)
    erann = create_arb_block(erann, 1, 1, 64)
    erann = create_arb_block(erann, 1, 1, 64)


    #Stage 4
    erann = create_arb_block(erann, 2, 2, 128)
    erann = create_arb_block(erann, 1, 1, 128)
    erann = create_arb_block(erann, 1, 1, 128)
    erann = create_arb_block(erann, 1, 1, 128)


    average_pool = layers.GlobalAveragePooling2D()(erann)
    erann = layers.Dense(128 * W)(average_pool)
    print(erann.shape)
    erann = layers.LeakyReLU(0.01)(erann)

    erann = layers.Dense(num_classes, activation='softmax')(erann)
    print(erann.shape)
    erann_model = models.Model(inputs=erann_input, outputs=erann)
    return erann_model

audio_input_shape = (128, 128, 1)
num_classes = 50 

sm_value = 1

eranns_model = create_eranns_architecture(audio_input_shape, sm_value, num_classes)

eranns_model.summary()
# Out:
# 2024-02-17 10:51:41.143068: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1
# 2024-02-17 10:51:41.143095: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2024-02-17 10:51:41.143103: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2024-02-17 10:51:41.143168: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-17 10:51:41.143217: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# (None, 128)
# (None, 50)
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 1)]        0         []
#
#  batch_normalization (Batch  (None, 128, 128, 1)          4         ['input_1[0][0]']
#  Normalization)
#
#  conv2d (Conv2D)             (None, 128, 128, 8)          80        ['batch_normalization[0][0]']
#
#  batch_normalization_1 (Bat  (None, 128, 128, 8)          32        ['conv2d[0][0]']
#  chNormalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 128, 128, 8)          0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 8)          584       ['leaky_re_lu[0][0]']
#
#  batch_normalization_2 (Bat  (None, 128, 128, 8)          32        ['conv2d_1[0][0]']
#  chNormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 128, 128, 8)          0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 128, 128, 8)          584       ['leaky_re_lu_1[0][0]']
#
#  batch_normalization_3 (Bat  (None, 128, 128, 8)          32        ['conv2d_2[0][0]']
#  chNormalization)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 128, 128, 8)          0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_3 (Conv2D)           (None, 128, 128, 8)          584       ['leaky_re_lu_2[0][0]']
#
#  batch_normalization_4 (Bat  (None, 128, 128, 8)          32        ['conv2d_3[0][0]']
#  chNormalization)
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 128, 128, 8)          0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv2d_4 (Conv2D)           (None, 128, 128, 8)          584       ['leaky_re_lu_3[0][0]']
#
#  batch_normalization_5 (Bat  (None, 128, 128, 8)          32        ['conv2d_4[0][0]']
#  chNormalization)
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 128, 128, 8)          0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  conv2d_5 (Conv2D)           (None, 128, 128, 8)          584       ['leaky_re_lu_4[0][0]']
#
#  batch_normalization_6 (Bat  (None, 128, 128, 8)          32        ['conv2d_5[0][0]']
#  chNormalization)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 128, 128, 8)          0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 128, 128, 8)          584       ['leaky_re_lu_5[0][0]']
#
#  batch_normalization_7 (Bat  (None, 128, 128, 8)          32        ['conv2d_6[0][0]']
#  chNormalization)
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 128, 128, 8)          0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  conv2d_7 (Conv2D)           (None, 128, 128, 8)          584       ['leaky_re_lu_6[0][0]']
#
#  batch_normalization_8 (Bat  (None, 128, 128, 8)          32        ['conv2d_7[0][0]']
#  chNormalization)
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 128, 128, 8)          0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_8 (Conv2D)           (None, 64, 32, 16)           2320      ['leaky_re_lu_7[0][0]']
#
#  batch_normalization_9 (Bat  (None, 64, 32, 16)           64        ['conv2d_8[0][0]']
#  chNormalization)
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 64, 32, 16)           0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  conv2d_9 (Conv2D)           (None, 64, 32, 16)           3856      ['leaky_re_lu_8[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 64, 32, 16)           144       ['conv2d_7[0][0]']
#
#  add (Add)                   (None, 64, 32, 16)           0         ['conv2d_9[0][0]',
#                                                                      'conv2d_10[0][0]']
#
#  dropout (Dropout)           (None, 64, 32, 16)           0         ['add[0][0]']
#
#  batch_normalization_10 (Ba  (None, 64, 32, 16)           64        ['dropout[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 64, 32, 16)           0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  conv2d_11 (Conv2D)          (None, 64, 32, 16)           2320      ['leaky_re_lu_9[0][0]']
#
#  batch_normalization_11 (Ba  (None, 64, 32, 16)           64        ['conv2d_11[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 64, 32, 16)           0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  conv2d_12 (Conv2D)          (None, 64, 32, 16)           2320      ['leaky_re_lu_10[0][0]']
#
#  batch_normalization_12 (Ba  (None, 64, 32, 16)           64        ['conv2d_12[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 64, 32, 16)           0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  conv2d_13 (Conv2D)          (None, 64, 32, 16)           2320      ['leaky_re_lu_11[0][0]']
#
#  batch_normalization_13 (Ba  (None, 64, 32, 16)           64        ['conv2d_13[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_12 (LeakyReLU)  (None, 64, 32, 16)           0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  conv2d_14 (Conv2D)          (None, 64, 32, 16)           2320      ['leaky_re_lu_12[0][0]']
#
#  batch_normalization_14 (Ba  (None, 64, 32, 16)           64        ['conv2d_14[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_13 (LeakyReLU)  (None, 64, 32, 16)           0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  conv2d_15 (Conv2D)          (None, 64, 32, 16)           2320      ['leaky_re_lu_13[0][0]']
#
#  batch_normalization_15 (Ba  (None, 64, 32, 16)           64        ['conv2d_15[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_14 (LeakyReLU)  (None, 64, 32, 16)           0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_16 (Conv2D)          (None, 64, 32, 16)           2320      ['leaky_re_lu_14[0][0]']
#
#  batch_normalization_16 (Ba  (None, 64, 32, 16)           64        ['conv2d_16[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_15 (LeakyReLU)  (None, 64, 32, 16)           0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_17 (Conv2D)          (None, 32, 16, 32)           4640      ['leaky_re_lu_15[0][0]']
#
#  batch_normalization_17 (Ba  (None, 32, 16, 32)           128       ['conv2d_17[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_16 (LeakyReLU)  (None, 32, 16, 32)           0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  conv2d_18 (Conv2D)          (None, 32, 16, 32)           9248      ['leaky_re_lu_16[0][0]']
#
#  conv2d_19 (Conv2D)          (None, 32, 16, 32)           544       ['conv2d_16[0][0]']
#
#  add_1 (Add)                 (None, 32, 16, 32)           0         ['conv2d_18[0][0]',
#                                                                      'conv2d_19[0][0]']
#
#  dropout_1 (Dropout)         (None, 32, 16, 32)           0         ['add_1[0][0]']
#
#  batch_normalization_18 (Ba  (None, 32, 16, 32)           128       ['dropout_1[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_17 (LeakyReLU)  (None, 32, 16, 32)           0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  conv2d_20 (Conv2D)          (None, 32, 16, 32)           9248      ['leaky_re_lu_17[0][0]']
#
#  batch_normalization_19 (Ba  (None, 32, 16, 32)           128       ['conv2d_20[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_18 (LeakyReLU)  (None, 32, 16, 32)           0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  conv2d_21 (Conv2D)          (None, 32, 16, 32)           9248      ['leaky_re_lu_18[0][0]']
#
#  batch_normalization_20 (Ba  (None, 32, 16, 32)           128       ['conv2d_21[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_19 (LeakyReLU)  (None, 32, 16, 32)           0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  conv2d_22 (Conv2D)          (None, 32, 16, 32)           9248      ['leaky_re_lu_19[0][0]']
#
#  batch_normalization_21 (Ba  (None, 32, 16, 32)           128       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_20 (LeakyReLU)  (None, 32, 16, 32)           0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  conv2d_23 (Conv2D)          (None, 32, 16, 32)           9248      ['leaky_re_lu_20[0][0]']
#
#  batch_normalization_22 (Ba  (None, 32, 16, 32)           128       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_21 (LeakyReLU)  (None, 32, 16, 32)           0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_24 (Conv2D)          (None, 32, 16, 32)           9248      ['leaky_re_lu_21[0][0]']
#
#  batch_normalization_23 (Ba  (None, 32, 16, 32)           128       ['conv2d_24[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_22 (LeakyReLU)  (None, 32, 16, 32)           0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  conv2d_25 (Conv2D)          (None, 32, 16, 32)           9248      ['leaky_re_lu_22[0][0]']
#
#  batch_normalization_24 (Ba  (None, 32, 16, 32)           128       ['conv2d_25[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_23 (LeakyReLU)  (None, 32, 16, 32)           0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  conv2d_26 (Conv2D)          (None, 16, 8, 64)            18496     ['leaky_re_lu_23[0][0]']
#
#  batch_normalization_25 (Ba  (None, 16, 8, 64)            256       ['conv2d_26[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_24 (LeakyReLU)  (None, 16, 8, 64)            0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  conv2d_27 (Conv2D)          (None, 16, 8, 64)            36928     ['leaky_re_lu_24[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 16, 8, 64)            2112      ['conv2d_25[0][0]']
#
#  add_2 (Add)                 (None, 16, 8, 64)            0         ['conv2d_27[0][0]',
#                                                                      'conv2d_28[0][0]']
#
#  dropout_2 (Dropout)         (None, 16, 8, 64)            0         ['add_2[0][0]']
#
#  batch_normalization_26 (Ba  (None, 16, 8, 64)            256       ['dropout_2[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_25 (LeakyReLU)  (None, 16, 8, 64)            0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  conv2d_29 (Conv2D)          (None, 16, 8, 64)            36928     ['leaky_re_lu_25[0][0]']
#
#  batch_normalization_27 (Ba  (None, 16, 8, 64)            256       ['conv2d_29[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_26 (LeakyReLU)  (None, 16, 8, 64)            0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  conv2d_30 (Conv2D)          (None, 16, 8, 64)            36928     ['leaky_re_lu_26[0][0]']
#
#  batch_normalization_28 (Ba  (None, 16, 8, 64)            256       ['conv2d_30[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_27 (LeakyReLU)  (None, 16, 8, 64)            0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  conv2d_31 (Conv2D)          (None, 16, 8, 64)            36928     ['leaky_re_lu_27[0][0]']
#
#  batch_normalization_29 (Ba  (None, 16, 8, 64)            256       ['conv2d_31[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_28 (LeakyReLU)  (None, 16, 8, 64)            0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  conv2d_32 (Conv2D)          (None, 16, 8, 64)            36928     ['leaky_re_lu_28[0][0]']
#
#  batch_normalization_30 (Ba  (None, 16, 8, 64)            256       ['conv2d_32[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_29 (LeakyReLU)  (None, 16, 8, 64)            0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  conv2d_33 (Conv2D)          (None, 16, 8, 64)            36928     ['leaky_re_lu_29[0][0]']
#
#  batch_normalization_31 (Ba  (None, 16, 8, 64)            256       ['conv2d_33[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_30 (LeakyReLU)  (None, 16, 8, 64)            0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  conv2d_34 (Conv2D)          (None, 16, 8, 64)            36928     ['leaky_re_lu_30[0][0]']
#
#  batch_normalization_32 (Ba  (None, 16, 8, 64)            256       ['conv2d_34[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_31 (LeakyReLU)  (None, 16, 8, 64)            0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  conv2d_35 (Conv2D)          (None, 8, 4, 128)            73856     ['leaky_re_lu_31[0][0]']
#
#  batch_normalization_33 (Ba  (None, 8, 4, 128)            512       ['conv2d_35[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_32 (LeakyReLU)  (None, 8, 4, 128)            0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  conv2d_36 (Conv2D)          (None, 8, 4, 128)            147584    ['leaky_re_lu_32[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 8, 4, 128)            8320      ['conv2d_34[0][0]']
#
#  add_3 (Add)                 (None, 8, 4, 128)            0         ['conv2d_36[0][0]',
#                                                                      'conv2d_37[0][0]']
#
#  dropout_3 (Dropout)         (None, 8, 4, 128)            0         ['add_3[0][0]']
#
#  batch_normalization_34 (Ba  (None, 8, 4, 128)            512       ['dropout_3[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_33 (LeakyReLU)  (None, 8, 4, 128)            0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv2d_38 (Conv2D)          (None, 8, 4, 128)            147584    ['leaky_re_lu_33[0][0]']
#
#  batch_normalization_35 (Ba  (None, 8, 4, 128)            512       ['conv2d_38[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_34 (LeakyReLU)  (None, 8, 4, 128)            0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  conv2d_39 (Conv2D)          (None, 8, 4, 128)            147584    ['leaky_re_lu_34[0][0]']
#
#  batch_normalization_36 (Ba  (None, 8, 4, 128)            512       ['conv2d_39[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_35 (LeakyReLU)  (None, 8, 4, 128)            0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  conv2d_40 (Conv2D)          (None, 8, 4, 128)            147584    ['leaky_re_lu_35[0][0]']
#
#  batch_normalization_37 (Ba  (None, 8, 4, 128)            512       ['conv2d_40[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_36 (LeakyReLU)  (None, 8, 4, 128)            0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  conv2d_41 (Conv2D)          (None, 8, 4, 128)            147584    ['leaky_re_lu_36[0][0]']
#
#  batch_normalization_38 (Ba  (None, 8, 4, 128)            512       ['conv2d_41[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_37 (LeakyReLU)  (None, 8, 4, 128)            0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 8, 4, 128)            147584    ['leaky_re_lu_37[0][0]']
#
#  batch_normalization_39 (Ba  (None, 8, 4, 128)            512       ['conv2d_42[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_38 (LeakyReLU)  (None, 8, 4, 128)            0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  conv2d_43 (Conv2D)          (None, 8, 4, 128)            147584    ['leaky_re_lu_38[0][0]']
#
#  global_average_pooling2d (  (None, 128)                  0         ['conv2d_43[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)                  16512     ['global_average_pooling2d[0][
#                                                                     0]']
#
#  leaky_re_lu_39 (LeakyReLU)  (None, 128)                  0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 50)                   6450      ['leaky_re_lu_39[0][0]']
#
# ==================================================================================================
# Total params: 1519086 (5.79 MB)
# Trainable params: 1515372 (5.78 MB)
# Non-trainable params: 3714 (14.51 KB)
# __________________________________________________________________________________________________

# %%
# plot model
tf.keras.utils.plot_model(
    eranns_model,
    to_file='model2.png',
    show_shapes=True,
    show_dtype=True,
    show_layer_names=True,
    rankdir='TB',
    expand_nested=True,
    dpi=96,
    layer_range=None,
    show_layer_activations=True,
    show_trainable=False
)

# %% [markdown]
# ### Function train_model

# %%
def train_model(model, train, label, model_file):

    checkpoint_filepath = f"model-erann/{model_file}.h5"
    checkpoint_callback = ModelCheckpoint(
        filepath=checkpoint_filepath,
        save_best_only=True,
        monitor="val_accuracy",
        mode="max",
        restore_best_weights=True,
        verbose=0,
    )

    model.compile(
        optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"]
    )

    model.fit(
        train,
        np.array(label),
        epochs=600,
        batch_size=50,
        validation_split=0.1,  # 1% of data for validation
        shuffle=True,
        use_multiprocessing=True,
        callbacks=[checkpoint_callback],
    )
    return model

# %% [markdown]
# ### Function test_model

# %%
## Test model
def test_model(model, test, label):
    test_loss, test_acc = model.evaluate(test,
        np.array(label),
    )
    return test_acc

# %% [markdown]
# #### Step 1 train model on pure data without augmentation

# %%
eranns_model = train_model(eranns_model, train, train_y,"intermdiate_model")
test_acc(eranns_model, test)

# %% [markdown]
# <bold>If training accuracy is low, we can run with more epochs</bold>

# %% [markdown]
# #### Step 2 adding augmentation to retrain to fine tune the model

# %%
train_aug2 = np.concatenate((train, aug_train))
train_y_aug2 = np.concatenate((train_y, aug_train_y))

# %% [markdown]
# #### Step 3 Retrain on new augmented

# %%
eranns_model = train_model(eranns_model, train_aug2, train_y_aug2, "aug_model")
test_acc(eranns_model, test)

# %% [markdown]
# # Test the model on previous run

# %%
from tensorflow.keras.models import load_model
model = load_model(f"/Users/Licious/project/unipd/hda_dataset/model-erann/checkpoint_prod_auto_1200_69.h5")
test_acc(eranns_model, test)
